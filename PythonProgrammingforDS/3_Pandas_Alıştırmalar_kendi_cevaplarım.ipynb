# %% [markdown]
# <a href="https://colab.research.google.com/github/ngamzedeniz/DS-Miuul/blob/main/Pandas_Al%C4%B1%C5%9Ft%C4%B1rmalar_kendi_cevaplar%C4%B1m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df["pclass"].nunique()
# Out:
# 3

# %%
df[["pclass","parch"]].nunique()
# Out:
# pclass    3
# parch     7
# dtype: int64

# %%
df["embarked"].dtypes
# Out:
# dtype('O')

# %%
df["embarked"].astype("category").dtypes
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %%
df[df["embarked"]=="C"].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 19         1       3  female   NaN      0      0   7.2250        C   Third
# 26         0       3    male   NaN      0      0   7.2250        C   Third
# 30         0       1    male  40.0      0      0  27.7208        C   First
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 9   child       False  NaN   Cherbourg   yes  False
# 19  woman       False  NaN   Cherbourg   yes   True
# 26    man        True  NaN   Cherbourg    no   True
# 30    man        True  NaN   Cherbourg    no   True

# %%
df[df["embarked"]!="S"].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 5     man        True  NaN  Queenstown    no   True
# 9   child       False  NaN   Cherbourg   yes  False
# 16  child       False  NaN  Queenstown    no  False
# 19  woman       False  NaN   Cherbourg   yes   True

# %%
df.loc[(df["age"]<30) & 
       (df["sex"] == "female")].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 14  child       False  NaN  Southampton    no   True

# %%
df.loc[(df["fare"] > 500) | (df["age"] > 70)].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# 630    man        True    A  Southampton   yes   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
del df["who"]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df["deck"].mode().values
# Out:
# ['C']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
	
df["deck"] = df["deck"].fillna(df["deck"].mode()[0])

# %%
df["age"].fillna(df["age"].median())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df.groupby(["pclass","sex"]).agg({"survived":["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# pclass sex
# 1      female       91    94  0.968085
#        male         45   122  0.368852
# 2      female       70    76  0.921053
#        male         17   108  0.157407
# 3      female       72   144  0.500000
#        male         47   347  0.135447

# %%
df["age_flag"] = df["age"].apply(lambda x: 1 if x < 30 else 0)

# %%
df["age_flag"].value_counts()
# Out:
# 0    507
# 1    384
# Name: age_flag, dtype: int64

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby(["time"]).agg({"total_bill":["min","max","mean"]})
# Out:
#        total_bill
#               min    max       mean
# time
# Lunch        7.51  43.11  17.168676
# Dinner       3.07  50.81  20.797159

# %%
df.groupby(["day","time"]).agg({"total_bill":["sum","min","max","mean"]})
# Out:
#             total_bill
#                    sum    min    max       mean
# day  time
# Thur Lunch     1077.55   7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.78  18.780000
# Fri  Lunch       89.92   8.58  16.27  12.845714
#      Dinner     235.96   5.75  40.17  19.663333
# Sat  Lunch        0.00    NaN    NaN        NaN
#      Dinner    1778.40   3.07  50.81  20.441379
# Sun  Lunch        0.00    NaN    NaN        NaN
#      Dinner    1627.16   7.25  48.17  21.410000

# %%
df.groupby([{"sex":"Female"},"time","day"]).agg({"total_bill":["sum","min","max","mean"],"tip":["sum","min","max","mean"]}).head()
# Out:
# Empty DataFrame
# Columns: [(total_bill, sum), (total_bill, min), (total_bill, max), (total_bill, mean), (tip, sum), (tip, min), (tip, max), (tip, mean)]
# Index: []

# %%
df.loc[(df["size"]<3) & 
       (df["total_bill"]>10)].mean()
# Out:
# <ipython-input-26-3b1e1a3c92fa>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[(df["size"]<3) &
# total_bill    17.184965
# tip            2.638811
# size           1.993007
# dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
total_bill_tip_sum = df.loc[:,['total_bill','tip']].sum(axis=1).sort_values().head(30)

# %%
total_bill_tip_sum
# Out:
# 67      4.07
# 92      6.75
# 111     8.25
# 195     9.00
# 218     9.18
# 149     9.51
# 135     9.76
# 145     9.85
# 126    10.00
# 222    10.50
# 6      10.77
# 30     11.00
# 43     11.00
# 235    11.32
# 53     11.50
# 148    11.51
# 75     11.76
# 82     11.90
# 10     11.98
# 1      12.00
# 16     12.00
# 226    12.09
# 117    12.15
# 168    12.20
# 233    12.24
# 136    12.33
# 196    12.34
# 172    12.40
# 169    12.63
# 132    12.67
# dtype: float64
